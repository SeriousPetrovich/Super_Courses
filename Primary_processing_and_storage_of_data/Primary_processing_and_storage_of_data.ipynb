# %%
import pandas as pd

# %%
df = pd.read_csv('Бакалавры_final_1.csv',sep=';')

# %%
df
# Out:
#      Группа  student_id  Упражнение 1: Упражнение. Архитектура ЭВМ и ОС  \
# 0     M3135      125699                                               0
# 1     R3130      171720                                               0
# 2     P3102      297557                                               0
# 3     M3139      359404                                               0
# 4     L3130      386308                                               0
# ...     ...         ...                                             ...
# 1389  R3136     1119940                                             100
# 1390  K3120      971326                                             100
# 1391  P3122      973798                                             100
# 1392  K3121     1001116                                             100
# 1393  P3110     1117045                                             100
#
#       Упражнение 2: Упражнение. Технологии программирования  \
# ...
